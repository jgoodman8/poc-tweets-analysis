# %% [markdown]
# # ETL - Preprocesado
#
# Utiliza Spark para procesar un dataset de Tweets en el formato original y responde a las preguntas.
#
# El archivo original que contiene los tweets contiene una carpeta por cada día, que a su vez contiene una carpeta por cada hora. Dentro de estas hay un archivo comprimido bz2 por cada minuto, que contiene un archivo JSON con los tweets en todos los idiomas enviados en ese intervalo. En la carpeta /files tienes los tweets del día 30/9/2011 en este formato (solo una hora, para ahorrar espacio).
#
# Utiliza Spark para extraer los tweets, interpretar el JSON y formatear los tweets en el formato adecuado.
# Deberás crear un array que contenga las rutas a los distintos archivos y transformarlo en un RDD con el que trabajar.
# Después deberás escribir una función con la que mapear una ruta de archivo a un listado de tuplas de la forma (**usuario, fecha, contenido_del_tweet**). A partir de ahí podrás manejar el RDD de la misma manera que en la práctica 2.
# Puedes coger ideas de este script que lee todos los archivos de un directorio y los descomprime del formato bz2.

# %%
import sys, os, bz2, json
from pyspark import SparkContext

tweets = []
json_files_paths = []
path = './tweets/30/01/'

def has_required_properties(tweet):
    return 'user' in tweet and 'created_at' in tweet and 'text' in tweet

for(dirpath,dirnames,files) in os.walk(path):
    for filename in files: 
        filepath = os.path.join(dirpath, filename) 
        json_file_path = filepath[:-4]        
        
        zipfile = bz2.BZ2File(filepath)
        data = zipfile.read()        
        open(json_file_path, 'wb').write(data)
        json_files_paths.append(json_file_path)

        with open(json_file_path, 'r') as json_stream:
            file_line = json_stream.readline()
            while file_line:
                json_parsed = json.loads(file_line)
                if has_required_properties(json_parsed):
                    tweets.append(json_parsed)
                file_line = json_stream.readline()
# Out:
# ['47.json.bz2', '44.json.bz2', '02.json.bz2', '21.json.bz2', '45.json.bz2', '43.json.bz2', '13.json.bz2', '07.json.bz2', '40.json.bz2', '31.json.bz2', '58.json.bz2', '10.json.bz2', '38.json.bz2', '23.json.bz2', '37.json.bz2', '30.json.bz2', '35.json.bz2', '59.json.bz2', '05.json.bz2', '26.json.bz2', '17.json.bz2', '52.json.bz2', '49.json.bz2', '39.json.bz2', '04.json.bz2', '55.json.bz2', '56.json.bz2', '48.json.bz2', '00.json.bz2', '08.json.bz2', '20.json.bz2', '42.json.bz2', '24.json.bz2', '28.json.bz2', '18.json.bz2', '25.json.bz2', '33.json.bz2', '36.json.bz2', '46.json.bz2', '41.json.bz2', '09.json.bz2', '16.json.bz2', '34.json.bz2', '57.json.bz2', '51.json.bz2', '32.json.bz2', '54.json.bz2', '14.json.bz2', '50.json.bz2', '01.json.bz2', '11.json.bz2', '06.json.bz2', '22.json.bz2', '27.json.bz2', '19.json.bz2', '53.json.bz2', '15.json.bz2', '03.json.bz2', '29.json.bz2', '12.json.bz2']

# %%
# Remove json files created
for json_path in json_files_paths:
    os.remove(json_path)

# %%
len(tweets)
# Out:
# 46562

# %%
# Tweet structure sample
print json.dumps(tweets[0], indent=4, sort_keys=True)
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Fri Sep 30 07:47:00 +0000 2011",
#     "entities": {
#         "hashtags": [],
#         "urls": [],
#         "user_mentions": []
#     },
#     "favorited": false,
#     "geo": null,
#     "id": 119679624430104576,
#     "id_str": "119679624430104576",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "place": null,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://ubersocial.com\" rel=\"nofollow\">UberSocial for Android</a>",
#     "text": "I think I mite sleep my whole day tomorrow I owe it to my body n mind",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Sun May 10 00:45:21 +0000 2009",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "MC,PRODUCER,TRUMPET PLAYER,SONG WRITTER,ACTOR,SCHOLAR,DIRECTOR,ARTEST,ACTIVIST,GAMER,STRONG BLACK MAN.....",
#         "favourites_count": 4,
#         "follow_request_sent": null,
#         "followers_count": 259,
#         "following": null,
#         "friends_count": 93,
#         "geo_enabled": false,
#         "id": 38962451,
#         "id_str": "38962451",
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 6,
#         "location": "OutWorld",
#         "name": "Rob Dot",
#         "notifications": null,
#         "profile_background_color": "1A1B1F",
#         "profile_background_image_url": "http://a2.twimg.com/profile_background_images/165424975/my_drawin_of_me.jpg",
#         "profile_background_image_url_https": "https://si0.twimg.com/profile_background_images/165424975/my_drawin_of_me.jpg",
#         "profile_background_tile": true,
#         "profile_image_url": "http://a1.twimg.com/profile_images/1152680793/robert_normal.jpg",
#         "profile_image_url_https": "https://si0.twimg.com/profile_images/1152680793/robert_normal.jpg",
#         "profile_link_color": "000000",
#         "profile_sidebar_border_color": "181A1E",
#         "profile_sidebar_fill_color": "252429",
#         "profile_text_color": "8c95a3",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "RobMillenium",
#         "show_all_inline_media": false,
#         "statuses_count": 7281,
#         "time_zone": "Quito",
#         "url": null,
#         "utc_offset": -18000,
#         "verified": false
#     }
# }

# %%
# Create context and load tweets

sc = SparkContext("local", "Tutorial")
rdd_tweets = sc.parallelize(tweets)
type(rdd_tweets)
# Out:
# pyspark.rdd.RDD

# %%
# Filter to get only tweets with language 'es'

def is_es_language(tweet):
    return tweet['user']['lang'] == 'es'

def format_tweet(tweet):
    return { 
        'user': tweet['user']['screen_name'],
        'text': tweet['text'], 
        'timestamp': tweet['created_at']
    }

rdd_tweets_es = (rdd_tweets
                 .filter(is_es_language) # Get tweets with language 'es'
                 .map(format_tweet)
                )


rdd_tweets_es.persist()
rdd_tweets_es.count()
# Out:
# 2137

# %%
# Formatted tweet sample
print json.dumps(rdd_tweets_es.take(10), indent=4, sort_keys=True)
# Out:
# [
#     {
#         "text": "@mariascc gracias cejuuuu!!! ^^",
#         "timestamp": "Fri Sep 30 07:47:00 +0000 2011",
#         "user": "USK_123Ska"
#     },
#     {
#         "text": "ma\u00f1ana viernes pesado todo mundo quiere salir de viaje y asi",
#         "timestamp": "Fri Sep 30 07:47:00 +0000 2011",
#         "user": "tiiimy"
#     },
#     {
#         "text": "@Monjeton @ot_panini_luna sale que descanses :)",
#         "timestamp": "Fri Sep 30 07:47:01 +0000 2011",
#         "user": "becan05"
#     },
#     {
#         "text": "@CacaitoLZF no te amargues por lo que no tiene remedio. Si no la olvidas, hazle creer que no la recuerdas.",
#         "timestamp": "Fri Sep 30 07:47:02 +0000 2011",
#         "user": "magde27"
#     },
#     {
#         "text": "recien vuelvo de Rumi, Niceto y Esperanto, la juventud/generaci\u00f3n esta perdida....",
#         "timestamp": "Fri Sep 30 07:47:07 +0000 2011",
#         "user": "NachoRockr"
#     },
#     {
#         "text": "@MarinaStriebeck. Jaja toppp modeelll http://t.co/xIVnjEb2",
#         "timestamp": "Fri Sep 30 07:47:09 +0000 2011",
#         "user": "florrmorrone"
#     },
#     {
#         "text": "Acabei de ler essa FIC &gt; http://t.co/mSAIG9BQ T\u00f4 chorando, s\u00e9rio! Muito linda *-*",
#         "timestamp": "Fri Sep 30 07:47:09 +0000 2011",
#         "user": "LuArLovers"
#     },
#     {
#         "text": "noooo no crean los m\u00e4nner esto somos debiles muy debiles! RT @UNoticias Las mujeres son \"el sexo fuerte\" seg\u00fan estudio http://t.co/SrpKilvg",
#         "timestamp": "Fri Sep 30 07:47:09 +0000 2011",
#         "user": "cristalortega"
#     },
#     {
#         "text": "Como dice pitbull 'si no hay carro nos vamooo en balsa' @edgarcinz1 hahahaa",
#         "timestamp": "Fri Sep 30 07:47:14 +0000 2011",
#         "user": "majoruano"
#     },
#     {
#         "text": "@jazarza12 puede ser, el momento lineal es pa los chocques y el retroceso de las armas de fuego",
#         "timestamp": "Fri Sep 30 07:47:15 +0000 2011",
#         "user": "Jlopespada"
#     }
# ]

# %% [markdown]
# ## Part 1

# %%
# Sort users by tweets made

total_tweets_by_user = (rdd_tweets_es
                        .map(lambda tweet: (tweet['user'], 1)) # Tuples (user, 1)
                        .reduceByKey(lambda value1, value2: value1 + value2) # Group by key (user) and sum #value
                        .sortBy(lambda tweet: tweet[1], ascending = False) # Sort by #value
                       )

# %%
# Top 10 users with more tweets
total_tweets_by_user.take(10)
# Out:
# [(u'AnnhaGarza', 4),
#  (u'berbe', 3),
#  (u'SamiiCruz', 3),
#  (u'Guille_Mi', 3),
#  (u'COGAM', 3),
#  (u'omerta_666', 3),
#  (u'Shushuna_Rangel', 3),
#  (u'LuisFer_05', 3),
#  (u'issixx', 3),
#  (u'ppaolart', 3)]

# %% [markdown]
# ## Part 2

# %%
# Sort by most recurrent words inside tweets' text

def get_text_splited_by_word(tweet):
    return tweet['text'].split()

tweets_words_sorted = (rdd_tweets_es
                       .flatMap(get_text_splited_by_word) # Make list with words from each tweet
                       .map(lambda word: (word, 1)) # Tuples (word, 1)
                       .reduceByKey(lambda value1, value2: value1 + value2) # Group by word and sum #value
                       .sortBy(lambda _tuple: _tuple[1], ascending=False) # Sort by #value
                      )

# %%
# Top common words inside tweets
tweets_words_sorted.take(10)
# Out:
# [(u'de', 714),
#  (u'a', 535),
#  (u'que', 508),
#  (u'la', 482),
#  (u'y', 397),
#  (u'en', 363),
#  (u'el', 354),
#  (u'RT', 328),
#  (u'no', 312),
#  (u'me', 278)]

# %% [markdown]
# ## Part 3

# %%
# Sort by most recurrent words inside tweets' text without most recurrent words inside the tweets (not in stopwords)

stopwords = ['como', 'pero', 'o', 'al', 'mas', 'esta', 'le', 'cuando', 'eso', 'su', 'porque',\
             'd', 'del', 'los', 'mi', 'si', 'las', 'una', 'q', 'ya', 'yo', 'tu', 'el', 'ella',\
             'a', 'ante', 'bajo', 'cabe', 'con', 'contra', 'de', 'desde', 'en', 'entre', 'hacia',\
             'hasta', 'para', 'por', 'segun', 'sin', 'so', 'sobre', 'tras', 'que', 'la', 'no', 'y',\
             'el', 'me', 'es', 'te', 'se', 'un', 'lo']

def is_not_stopword(item):
    return item[0] not in stopwords

tweets_words_sorted.persist()
tweets_words_sorted_filtered = (tweets_words_sorted
                                .filter(is_not_stopword) # Remove stopwords from sorted tuples (word, #value)
                                .sortBy(lambda _tuple: _tuple[1], ascending=False) # Sort by #value
                               )

# %%
# Top common words inside tweets (not in stopwords)
tweets_words_sorted_filtered.take(10)
# Out:
# [(u'RT', 328),
#  (u'...', 83),
#  (u'El', 63),
#  (u'No', 53),
#  (u'-', 52),
#  (u':)', 50),
#  (u'A', 49),
#  (u'La', 49),
#  (u'Y', 46),
#  (u'ver', 41)]

# %% [markdown]
# ## Part 4

# %%
# Get scope (number of apperances) by hashtag

def get_hashtags(tweet):
    hashtags=tweet['text'].split('#')[1:]
    return map(lambda x: x if ' ' not in x.lower() else x.partition(' ')[0].lower(), hashtags)

def has_elements(item):
    return len(item) > 0

hashtags_sorted = (rdd_tweets_es
                   .flatMap(get_hashtags) # Extract list of hashtag from text
                   .map(lambda hashtag: (hashtag, 1)) # Tuples (hashtag, 1)
                   .reduceByKey(lambda value1, value2: value1 + value2) # Group by hashtag and compute #value
                   .sortBy(lambda _tuple: _tuple[1], ascending=False) # Sort by #value
                  )

hashtags_sorted.persist()
hashtags_sorted_list = hashtags_sorted.collect()
hashtags_sorted_list
# Out:
# [(u'ff', 44),
#  (u'cuandomedrogo', 8),
#  (u'fb', 6),
#  (u'np', 5),
#  (u'pinchesnombresculeros', 4),
#  (u'followback', 4),
#  (u'comiquitasdelainfancia', 3),
#  (u'ches', 3),
#  (u'trabajo', 3),
#  (u'latinoamericac13', 3),
#  (u'twitteroff', 3),
#  (u'siguemeytesigo', 3),
#  (u'twitter', 3),
#  (u'nowplaying', 3),
#  (u'estanochequiero', 2),
#  (u'panama', 2),
#  (u'follow1x1', 2),
#  (u'talibanazoxcrisuentv', 2),
#  (u'followrapido', 2),
#  (u'oseaguats', 2),
#  (u'cchsur', 2),
#  (u'TalibanazoxCrisUenTv', 2),
#  (u'empleo', 2),
#  (u'fail', 2),
#  (u'economia', 2),
#  (u'sifueramiultimanoche', 2),
#  (u'', 1),
#  (u'thingsmenshouldnttexteachother', 1),
#  (u'wTF', 1),
#  (u'dios', 1),
#  (u'Two0F', 1),
#  (u'ppsoe', 1),
#  (u'paris', 1),
#  (u'voluntariado', 1),
#  (u'CasosDeLaBidaReal"', 1),
#  (u'facebook', 1),
#  (u'useyourillusioni', 1),
#  (u'casa', 1),
#  (u'NovemberRain', 1),
#  (u'omaigadauran', 1),
#  (u'team', 1),
#  (u'teamfollowback', 1),
#  (u'cchsur,', 1),
#  (u'espregunta', 1),
#  (u'Carloscanta2407.11FM', 1),
#  (u'htcdesireven', 1),
#  (u'90s', 1),
#  (u'cazailegalaves', 1),
#  (u'nowords', 1),
#  (u'decoraci\xf3n', 1),
#  (u'turismo', 1),
#  (u'c\xe1ncer:', 1),
#  (u'lgbt', 1),
#  (u'golfbarapestas', 1),
#  (u'muerteaplatini', 1),
#  (u'MtvMomentos.', 1),
#  (u'alwaysonmymind', 1),
#  (u'culturapreventiva', 1),
#  (u'mobilemarketing', 1),
#  (u'notitec', 1),
#  (u'4950', 1),
#  (u'avene', 1),
#  (u'Pasalo', 1),
#  (u'FB', 1),
#  (u'2000s', 1),
#  (u'FF', 1),
#  (u'yyomequedecomoqueahok', 1),
#  (u'iphone', 1),
#  (u'culturateceriana', 1),
#  (u'noesdedios!!', 1),
#  (u'estonoesvida', 1),
#  (u'landashop?', 1),
#  (u'Nohayderexo!', 1),
#  (u'vuelta', 1),
#  (u'europapress', 1),
#  (u'hola', 1),
#  (u'jamas', 1),
#  (u'dormire', 1),
#  (u'enelbarrionuncafalta', 1),
#  (u'yosoyviernes', 1),
#  (u'noalaborto', 1),
#  (u'laculpaesdel15m', 1),
#  (u'INDICO', 1),
#  (u'PalantMrik', 1),
#  (u'monumentmessi,', 1),
#  (u'antoine', 1),
#  (u'30a\xf1osdeoscuridad', 1),
#  (u'guias', 1),
#  (u'hoy', 1),
#  (u'cosm\xe9tica', 1),
#  (u'beauty', 1),
#  (u'risas', 1),
#  (u'diarionavarra', 1),
#  (u'twitterfuckingoff', 1),
#  (u'Mexico', 1),
#  (u'gunsandroses', 1),
#  (u'emperorado', 1),
#  (u'LaIntencionEsLoQueCuenta', 1),
#  (u'fcosanchezcorona', 1),
#  (u'animeid', 1),
#  (u'convivenciatwitter', 1),
#  (u'doubledoubleproteinstyle', 1),
#  (u'ilustraciones?', 1),
#  (u'suicidio', 1),
#  (u'puntaarenas', 1),
#  (u'thegadafians', 1),
#  (u'hypocrisy', 1),
#  (u'ln', 1),
#  (u'coaching', 1),
#  (u'WTF', 1),
#  (u'maquillaje', 1),
#  (u'argentina', 1),
#  (u'ceo', 1),
#  (u'matarme!', 1),
#  (u'nervios', 1),
#  (u'buenasnoches', 1),
#  (u'frasespreviasaldesastre', 1),
#  (u'odio', 1),
#  (u'solangistahastalamuerte', 1),
#  (u'las_ventas_de_albares', 1),
#  (u'esunaestafa', 1),
#  (u'desahuciojerez', 1),
#  (u'vergonzoso', 1),
#  (u'buenosd\xedas', 1),
#  (u'smallbiz\u201d', 1),
#  (u'dpremsa', 1),
#  (u'opini\xf3n:', 1),
#  (u'veracruz', 1),
#  (u'situacionestragametierra', 1),
#  (u'canada', 1),
#  (u'TwOFF', 1),
#  (u'FrasesNietzsche', 1),
#  (u'mtyfollow', 1),
#  (u'70s', 1),
#  (u'folleufor\xe7a', 1),
#  (u'redessociales', 1),
#  (u'losdesayunosdetve', 1),
#  (u'Madrid', 1),
#  (u'norecursomat', 1),
#  (u'sanidad', 1),
#  (u'nuevoCDdunedain', 1),
#  (u'vullveuremusculmanja', 1),
#  (u'nomamar', 1),
#  (u'cancelomitwitter', 1),
#  (u'quierounanovia', 1),
#  (u'TwOff', 1),
#  (u'so\xf1ando', 1),
#  (u'aupaathletic', 1),
#  (u'speaking', 1),
#  (u'soycutre', 1),
#  (u'SiguemeYTesigo', 1),
#  (u'TwitterOff', 1),
#  (u'Siafuerzas', 1),
#  (u'desarrollohumano', 1),
#  (u'formador', 1),
#  (u'PMI', 1),
#  (u'1!', 1),
#  (u'r', 1),
#  (u'redneutral,', 1),
#  (u'trafico', 1),
#  (u'patapalo', 1),
#  (u'madrugando', 1),
#  (u'belleza', 1),
#  (u'lopd', 1),
#  (u'viernessocial', 1),
#  (u'mecagoentodo', 1),
#  (u'linda', 1),
#  (u'buenosdias', 1),
#  (u'gunsnroses', 1),
#  (u'dontcry', 1),
#  (u'momentocursi', 1),
#  (u'fcc', 1),
#  (u'internacionalizacion', 1),
#  (u'inda', 1),
#  (u'publicidad', 1),
#  (u'het.', 1),
#  (u'llevameprontose\xf1or', 1),
#  (u'derechoadecidir', 1),
#  (u'lujo', 1),
#  (u'Esoooo', 1),
#  (u'yallegue', 1),
#  (u'FFantazine', 1),
#  (u'acne', 1),
#  (u'QuieroaMam\xe1', 1),
#  (u'antoniovchanal', 1),
#  (u'RERetribution', 1),
#  (u'OFF', 1),
#  (u'TVE.', 1),
#  (u'webapp:', 1),
#  (u'quepesaaa', 1),
#  (u'foreveralone', 1),
#  (u'palde', 1),
#  (u'haveaniceday', 1),
#  (u'felipe', 1),
#  (u'faunadelmetro.', 1),
#  (u'RadiodelPlata', 1),
#  (u'hedicho', 1),
#  (u'vino', 1),
#  (u'congresoscivil', 1),
#  (u'empleo@learning.es', 1),
#  (u'analytics', 1),
#  (u'cultura', 1),
#  (u'publicidad.', 1),
#  (u'bondia', 1),
#  (u'oferta', 1),
#  (u'notecanses', 1),
#  (u'pets', 1),
#  (u'LaOpini\xf3nCoru\xf1a', 1),
#  (u'chicocomun', 1),
#  (u'ehyker', 1),
#  (u'piensoque', 1),
#  (u'FollowVenezuela', 1),
#  (u'wtf', 1),
#  (u'melapelo', 1),
#  (u'nowlistening', 1),
#  (u'NOrecursomatrimonioPP', 1),
#  (u'lacrudaverdad', 1),
#  (u'AyYaMaricoQueTeComaUnTiburon', 1),
#  (u'unpesomenos', 1),
#  (u'frasesdecurao', 1),
#  (u'tecno', 1),
#  (u'cuando', 1),
#  (u'leon', 1),
#  (u'gamberra', 1),
#  (u'lleida,', 1),
#  (u'reto', 1),
#  (u'pb', 1),
#  (u'IHope', 1),
#  (u'username', 1),
#  (u'politica', 1),
#  (u'comoenamora', 1),
#  (u'bilinguismo', 1),
#  (u'46.', 1),
#  (u'chile', 1),
#  (u'ffback', 1),
#  (u'viigoaf', 1),
#  (u'unanoviaque', 1),
#  (u'hastag', 1),
#  (u'SuicidioInmediato', 1),
#  (u'buenasmadrugadas', 1),
#  (u'MichinOff', 1),
#  (u'CIHBE11', 1),
#  (u'BritneySpearsQuotes', 1),
#  (u'NSN', 1),
#  (u'notcool', 1),
#  (u'tqm', 1),
#  (u'followers', 1),
#  (u'madera,', 1),
#  (u'80s', 1),
#  (u'castellano', 1),
#  (u'comiquitaquenuncamuere', 1),
#  (u'tiempo', 1),
#  (u'collapessigolla', 1),
#  (u'somebodykillme!!!!', 1),
#  (u'TuiterOFF', 1),
#  (u'hosteler\xeda', 1),
#  (u'verfollow', 1),
#  (u'muerteydestrucci\xf3n', 1),
#  (u'ttlarioja', 1),
#  (u'piupiuNet', 1),
#  (u'oidoenlaofi', 1),
#  (u'tufollow', 1),
#  (u'xalapa', 1),
#  (u'tipico', 1),
#  (u'prensasocial', 1),
#  (u'turismo,', 1),
#  (u'cosmetica', 1),
#  (u'tuiempleo.', 1),
#  (u'Poetuit', 1),
#  (u'lopedevega', 1),
#  (u'bestwishes', 1),
#  (u'MENEALO', 1),
#  (u'QuererQuerernos', 1),
#  (u'epidemia', 1),
#  (u'asiquelepegarealapersonaquelahaceponertristeami', 1),
#  (u'teamdomincan', 1),
#  (u'chinazosenvideojuegos', 1),
#  (u'Salsita', 1),
#  (u'bolsa', 1),
#  (u'pormamon', 1),
#  (u'gordooooooooo', 1),
#  (u'finanzas', 1),
#  (u'rubalcaba', 1),
#  (u'okno', 1),
#  (u'ComoYellow', 1),
#  (u'twttOff', 1),
#  (u'QueArrechooooNo\xbf?', 1),
#  (u'madrid', 1),
#  (u'30s', 1),
#  (u"bandaampla\nl'administraci\xf3", 1),
#  (u'humor', 1),
#  (u'cv', 1),
#  (u'amoaminovia', 1),
#  (u'TTLaRioja', 1),
#  (u'fifa12', 1),
#  (u'justincancelamexico', 1),
#  (u'followmexico', 1),
#  (u'marketing', 1),
#  (u'norecursoma', 1),
#  (u'pened\xe8s', 1),
#  (u'sabiasque', 1),
#  (u'on', 1),
#  (u'netflix', 1),
#  (u'arturmas', 1),
#  (u'UE', 1),
#  (u'NOrecursoMatrimonioPP', 1),
#  (u'discapacidad', 1),
#  (u'tecnologia', 1),
#  (u'DecididoMeMudar\xe9Al\xc1reaLim\xedtrofe', 1),
#  (u'mcdetos', 1),
#  (u'simesiguesyotesigo', 1),
#  (u'lovelovelove', 1),
#  (u'soyandaluz', 1),
#  (u'saludodesdeasturias', 1),
#  (u'aytancrecido', 1),
#  (u'mascotas', 1),
#  (u'viajes', 1),
#  (u'CCHSUR', 1),
#  (u'lonecesito', 1),
#  (u'TeAmo', 1),
#  (u'FollowMe', 1),
#  (u'felizaniversario', 1),
#  (u'liveandletdie', 1),
#  (u'tengoganasdeverte', 1),
#  (u'ht', 1),
#  (u'racistas', 1),
#  (u'llegaeldia', 1),
#  (u'venezuela?', 1),
#  (u'blogs', 1),
#  (u'visitascesa', 1),
#  (u'tarado!', 1),
#  (u'pib', 1),
#  (u'Arturmassieso', 1),
#  (u'sales', 1),
#  (u'echaunvistazo', 1),
#  (u'paraguay', 1),
#  (u'granada', 1),
#  (u'prepa5rules', 1),
#  (u'tforce', 1),
#  (u'ecuaruffita', 1),
#  (u'rumboalapresidencia', 1),
#  (u'fightingwords', 1),
#  (u'followseguro', 1),
#  (u'ffpara', 1),
#  (u'bizbarcelona', 1),
#  (u'a6', 1),
#  (u'papu', 1),
#  (u'2008', 1),
#  (u'lucip', 1),
#  (u'e', 1),
#  (u'mundodelcorazon', 1),
#  (u'rrss', 1),
#  (u'VaAValir!', 1),
#  (u'empleo:', 1)]

# %%
# Sort users by sum of used hashtags' scope

def get_scope(value):
    scope = [_tuple2_[1] for _tuple2_ in hashtags_sorted_list if _tuple2_[0] == value]
    return scope[0]

hashtags_grouped_by_user_sorted = (rdd_tweets_es
                                   .map(lambda tweet: (tweet['user'], get_hashtags(tweet))) # Tuple (user,[hashtag])
                                   .filter(lambda item: has_elements(item[1])) # Remove tuples without hashtags
                                   .flatMapValues(lambda value: value) # Make list of (user, hashtag)
                                   .map(lambda item: (item[0], get_scope(item[1]))) # Tuple (user, scope)
                                   .reduceByKey(lambda v1, v2: v1 + v2) # Group by user and sum #value
                                   .sortBy(lambda item: item[1], ascending=False) # Sort by #value
                                  )

# %%
# Top 10 user by scope of used hashtags
hashtags_grouped_by_user_sorted.take(10)
# Out:
# [(u'Perro_de_Cris_U', 46),
#  (u'issixx', 46),
#  (u'luisdiazdeldedo', 45),
#  (u'ibotica', 45),
#  (u'mundodelcorazon', 45),
#  (u'JcPxnditx91', 45),
#  (u'Bouquet_es', 44),
#  (u'ElPan_', 44),
#  (u'Kev_Aponte', 44),
#  (u'AmaaliaGo', 44)]

# %% [markdown]
# ## Part 5

# %%
# Get useless hashtags (scope = 1)
useless_hashtags = map(lambda pair: pair[0], filter(lambda pair: pair[1] == 1,hashtags_sorted_list))
useless_hashtags
# Out:
# [u'',
#  u'thingsmenshouldnttexteachother',
#  u'wTF',
#  u'dios',
#  u'Two0F',
#  u'ppsoe',
#  u'paris',
#  u'voluntariado',
#  u'CasosDeLaBidaReal"',
#  u'facebook',
#  u'useyourillusioni',
#  u'casa',
#  u'NovemberRain',
#  u'omaigadauran',
#  u'team',
#  u'teamfollowback',
#  u'cchsur,',
#  u'espregunta',
#  u'Carloscanta2407.11FM',
#  u'htcdesireven',
#  u'90s',
#  u'cazailegalaves',
#  u'nowords',
#  u'decoraci\xf3n',
#  u'turismo',
#  u'c\xe1ncer:',
#  u'lgbt',
#  u'golfbarapestas',
#  u'muerteaplatini',
#  u'MtvMomentos.',
#  u'alwaysonmymind',
#  u'culturapreventiva',
#  u'mobilemarketing',
#  u'notitec',
#  u'4950',
#  u'avene',
#  u'Pasalo',
#  u'FB',
#  u'2000s',
#  u'FF',
#  u'yyomequedecomoqueahok',
#  u'iphone',
#  u'culturateceriana',
#  u'noesdedios!!',
#  u'estonoesvida',
#  u'landashop?',
#  u'Nohayderexo!',
#  u'vuelta',
#  u'europapress',
#  u'hola',
#  u'jamas',
#  u'dormire',
#  u'enelbarrionuncafalta',
#  u'yosoyviernes',
#  u'noalaborto',
#  u'laculpaesdel15m',
#  u'INDICO',
#  u'PalantMrik',
#  u'monumentmessi,',
#  u'antoine',
#  u'30a\xf1osdeoscuridad',
#  u'guias',
#  u'hoy',
#  u'cosm\xe9tica',
#  u'beauty',
#  u'risas',
#  u'diarionavarra',
#  u'twitterfuckingoff',
#  u'Mexico',
#  u'gunsandroses',
#  u'emperorado',
#  u'LaIntencionEsLoQueCuenta',
#  u'fcosanchezcorona',
#  u'animeid',
#  u'convivenciatwitter',
#  u'doubledoubleproteinstyle',
#  u'ilustraciones?',
#  u'suicidio',
#  u'puntaarenas',
#  u'thegadafians',
#  u'hypocrisy',
#  u'ln',
#  u'coaching',
#  u'WTF',
#  u'maquillaje',
#  u'argentina',
#  u'ceo',
#  u'matarme!',
#  u'nervios',
#  u'buenasnoches',
#  u'frasespreviasaldesastre',
#  u'odio',
#  u'solangistahastalamuerte',
#  u'las_ventas_de_albares',
#  u'esunaestafa',
#  u'desahuciojerez',
#  u'vergonzoso',
#  u'buenosd\xedas',
#  u'smallbiz\u201d',
#  u'dpremsa',
#  u'opini\xf3n:',
#  u'veracruz',
#  u'situacionestragametierra',
#  u'canada',
#  u'TwOFF',
#  u'FrasesNietzsche',
#  u'mtyfollow',
#  u'70s',
#  u'folleufor\xe7a',
#  u'redessociales',
#  u'losdesayunosdetve',
#  u'Madrid',
#  u'norecursomat',
#  u'sanidad',
#  u'nuevoCDdunedain',
#  u'vullveuremusculmanja',
#  u'nomamar',
#  u'cancelomitwitter',
#  u'quierounanovia',
#  u'TwOff',
#  u'so\xf1ando',
#  u'aupaathletic',
#  u'speaking',
#  u'soycutre',
#  u'SiguemeYTesigo',
#  u'TwitterOff',
#  u'Siafuerzas',
#  u'desarrollohumano',
#  u'formador',
#  u'PMI',
#  u'1!',
#  u'r',
#  u'redneutral,',
#  u'trafico',
#  u'patapalo',
#  u'madrugando',
#  u'belleza',
#  u'lopd',
#  u'viernessocial',
#  u'mecagoentodo',
#  u'linda',
#  u'buenosdias',
#  u'gunsnroses',
#  u'dontcry',
#  u'momentocursi',
#  u'fcc',
#  u'internacionalizacion',
#  u'inda',
#  u'publicidad',
#  u'het.',
#  u'llevameprontose\xf1or',
#  u'derechoadecidir',
#  u'lujo',
#  u'Esoooo',
#  u'yallegue',
#  u'FFantazine',
#  u'acne',
#  u'QuieroaMam\xe1',
#  u'antoniovchanal',
#  u'RERetribution',
#  u'OFF',
#  u'TVE.',
#  u'webapp:',
#  u'quepesaaa',
#  u'foreveralone',
#  u'palde',
#  u'haveaniceday',
#  u'felipe',
#  u'faunadelmetro.',
#  u'RadiodelPlata',
#  u'hedicho',
#  u'vino',
#  u'congresoscivil',
#  u'empleo@learning.es',
#  u'analytics',
#  u'cultura',
#  u'publicidad.',
#  u'bondia',
#  u'oferta',
#  u'notecanses',
#  u'pets',
#  u'LaOpini\xf3nCoru\xf1a',
#  u'chicocomun',
#  u'ehyker',
#  u'piensoque',
#  u'FollowVenezuela',
#  u'wtf',
#  u'melapelo',
#  u'nowlistening',
#  u'NOrecursomatrimonioPP',
#  u'lacrudaverdad',
#  u'AyYaMaricoQueTeComaUnTiburon',
#  u'unpesomenos',
#  u'frasesdecurao',
#  u'tecno',
#  u'cuando',
#  u'leon',
#  u'gamberra',
#  u'lleida,',
#  u'reto',
#  u'pb',
#  u'IHope',
#  u'username',
#  u'politica',
#  u'comoenamora',
#  u'bilinguismo',
#  u'46.',
#  u'chile',
#  u'ffback',
#  u'viigoaf',
#  u'unanoviaque',
#  u'hastag',
#  u'SuicidioInmediato',
#  u'buenasmadrugadas',
#  u'MichinOff',
#  u'CIHBE11',
#  u'BritneySpearsQuotes',
#  u'NSN',
#  u'notcool',
#  u'tqm',
#  u'followers',
#  u'madera,',
#  u'80s',
#  u'castellano',
#  u'comiquitaquenuncamuere',
#  u'tiempo',
#  u'collapessigolla',
#  u'somebodykillme!!!!',
#  u'TuiterOFF',
#  u'hosteler\xeda',
#  u'verfollow',
#  u'muerteydestrucci\xf3n',
#  u'ttlarioja',
#  u'piupiuNet',
#  u'oidoenlaofi',
#  u'tufollow',
#  u'xalapa',
#  u'tipico',
#  u'prensasocial',
#  u'turismo,',
#  u'cosmetica',
#  u'tuiempleo.',
#  u'Poetuit',
#  u'lopedevega',
#  u'bestwishes',
#  u'MENEALO',
#  u'QuererQuerernos',
#  u'epidemia',
#  u'asiquelepegarealapersonaquelahaceponertristeami',
#  u'teamdomincan',
#  u'chinazosenvideojuegos',
#  u'Salsita',
#  u'bolsa',
#  u'pormamon',
#  u'gordooooooooo',
#  u'finanzas',
#  u'rubalcaba',
#  u'okno',
#  u'ComoYellow',
#  u'twttOff',
#  u'QueArrechooooNo\xbf?',
#  u'madrid',
#  u'30s',
#  u"bandaampla\nl'administraci\xf3",
#  u'humor',
#  u'cv',
#  u'amoaminovia',
#  u'TTLaRioja',
#  u'fifa12',
#  u'justincancelamexico',
#  u'followmexico',
#  u'marketing',
#  u'norecursoma',
#  u'pened\xe8s',
#  u'sabiasque',
#  u'on',
#  u'netflix',
#  u'arturmas',
#  u'UE',
#  u'NOrecursoMatrimonioPP',
#  u'discapacidad',
#  u'tecnologia',
#  u'DecididoMeMudar\xe9Al\xc1reaLim\xedtrofe',
#  u'mcdetos',
#  u'simesiguesyotesigo',
#  u'lovelovelove',
#  u'soyandaluz',
#  u'saludodesdeasturias',
#  u'aytancrecido',
#  u'mascotas',
#  u'viajes',
#  u'CCHSUR',
#  u'lonecesito',
#  u'TeAmo',
#  u'FollowMe',
#  u'felizaniversario',
#  u'liveandletdie',
#  u'tengoganasdeverte',
#  u'ht',
#  u'racistas',
#  u'llegaeldia',
#  u'venezuela?',
#  u'blogs',
#  u'visitascesa',
#  u'tarado!',
#  u'pib',
#  u'Arturmassieso',
#  u'sales',
#  u'echaunvistazo',
#  u'paraguay',
#  u'granada',
#  u'prepa5rules',
#  u'tforce',
#  u'ecuaruffita',
#  u'rumboalapresidencia',
#  u'fightingwords',
#  u'followseguro',
#  u'ffpara',
#  u'bizbarcelona',
#  u'a6',
#  u'papu',
#  u'2008',
#  u'lucip',
#  u'e',
#  u'mundodelcorazon',
#  u'rrss',
#  u'VaAValir!',
#  u'empleo:']

# %%
# Get users sorted by more useless hashtags created

def is_useless_hashtag(item):
    return item[1] in useless_hashtags

useless_hashtags_creators = (rdd_tweets_es
                             .map(lambda tweet: (tweet['user'], get_hashtags(tweet))) # Tuple (user,[hashtag])
                             .filter(lambda item: has_elements(item[1])) # Remove tuples without hashtags
                             .flatMapValues(lambda value: value) # Make list of (user, hashtag)
                             .filter(is_useless_hashtag) # Filter to get only useless hashtags
                             .map(lambda item: (item[0], 1)) # Tuple (hashtag, 1)
                             .reduceByKey(lambda v1, v2: v1 + v2) # Group by user and sum #value
                             .sortBy(lambda item: item[1], ascending = False) # Sort by #value
                            )

# %%
# Top 10 creators of useless hashtags
useless_hashtags_creators.take(10)
# Out:
# [(u'bindupowercoach', 7),
#  (u'MiRadioTweet', 5),
#  (u'mplzoe', 5),
#  (u'patriotdarkwolf', 5),
#  (u'COGAM', 4),
#  (u'fluisvives', 4),
#  (u'Hoyreka', 4),
#  (u'Tweet_Pub', 4),
#  (u'Chica_Vnzla', 4),
#  (u'tuitrafico_feed', 4)]

# %% [markdown]
# ## Part 6

# %%
# Users who created hashtags with more scope

def get_creator(pairs):
    pair_as_list_sorted = sorted(list(pairs), key = lambda item: item[1])
    return pair_as_list_sorted[0][0]

def format_tuples(item):
    return (item[1], (item[0]['user'], item[0]['timestamp']))

hashtag_creators_by_scope = (rdd_tweets_es
                             .sortBy(lambda tweet: tweet['timestamp'], ascending=True)  # Sort by timestamp    
                             .map(lambda tweet: (tweet, get_hashtags(tweet))) # Extract hashtags from text
                             .filter(lambda item: has_elements(item[1])) # Remove tuples without hashtags
                             .flatMapValues(lambda value: value) # Tuples (user, hashtag)
                             .map(format_tuples) # Create tuples (hashtag, (user, timestamp))
                             .groupByKey() # Group by hashtag
                             .map(lambda (key, value): (key, get_creator(value))) # Get hashtag creators
                             .map(lambda item: (item[1], get_scope(item[0]))) # Tuples (user, scope)
                             .reduceByKey(lambda v1, v2: v1 + v2) # Compute the accumulated scope from each user
                             .sortBy(lambda item: item[1], ascending=False) # Sort by accumulated scope
                            )

# %%
hashtag_creators_by_scope.take(10)
# Out:
# [(u'FabianaMargarit', 44),
#  (u'mplzoe', 12),
#  (u'WilDonME', 8),
#  (u'bindupowercoach', 7),
#  (u'cursos_ceticsa', 6),
#  (u'AiramMedranoMue', 6),
#  (u'sergisbarnosell', 6),
#  (u'MiRadioTweet', 5),
#  (u'AliciaDinorah', 5),
#  (u'KaroCaiaffa', 5)]
